# %%
a = 1
print(a)
# Out:
# 1

# %%
# Setup system path
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, '../src')

# Add examples to path  
sys.path.insert(0, '../examples')

# %%
# Import functions from the test script
from test_agents import test_single_agent, test_agent_vs_agent, play_game

# %%
# Run the test of the single agent
test_single_agent()

# %%
# Test agent vs. agent
test_agent_vs_agent()
